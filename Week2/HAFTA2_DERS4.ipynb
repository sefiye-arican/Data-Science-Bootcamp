# %%
import pandas as pd
import numpy as np

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
data = pd.read_csv("C:/Users/DELL/Desktop/veri bilimi kampı/winequality-red.csv")
df= data.copy()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
pd.cut(df['quality'], bins=3).value_counts()
# Out:
# quality
# (4.667, 6.333]    1319
# (6.333, 8.0]       217
# (2.995, 4.667]      63
# Name: count, dtype: int64

# %%
pd.cut(df['quality'], bins=3, labels=False).value_counts() #cut ta 3e bölüyoruz sınıfı 3 anlamlı sınıf yapacak
# Out:
# quality
# 1    1319
# 2     217
# 0      63
# Name: count, dtype: int64

# %%
df['quality'] = pd.cut(df['quality'], bins=3, labels=False)

# %%
df['quality'].value_counts()
# Out:
# quality
# 1    1319
# 2     217
# 0      63
# Name: count, dtype: int64

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=20) #skoru verirken etrafında ne kadar yakın veri var ona göre aykırı değer analizi yap
outlier_scores =lof.fit_predict(df)

np.where(outlier_scores == -1)[0] #aykırı değerler -1 ile gösterilir
# Out:
# array([ 324,  325,  354,  374,  396,  400,  442,  444,  480,  530,  535,
#         538,  559,  564,  652,  773,  774,  911,  917,  923,  974,  982,
#        1043, 1079, 1081, 1131, 1186, 1235, 1244, 1558, 1574], dtype=int64)

# %%
df.loc[np.where(outlier_scores == -1)[0]]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 324            10.0             0.490         0.20            11.0      0.071
# 325            10.0             0.490         0.20            11.0      0.071
# 354             6.1             0.210         0.40             1.4      0.066
# 374            14.0             0.410         0.63             3.8      0.089
# 396             6.6             0.735         0.02             7.9      0.122
# 400             6.6             0.735         0.02             7.9      0.122
# 442            15.6             0.685         0.76             3.7      0.100
# 444             5.3             0.570         0.01             1.7      0.054
# 480            10.6             0.280         0.39            15.5      0.069
# 530             9.1             0.220         0.24             2.1      0.078
# 535             9.1             0.220         0.24             2.1      0.078
# ...

# %%
len(np.where(outlier_scores == -1)[0]) /df.shape[0]*100
# Out:
# 1.938711694809256

# %%
mean_values =df.mean()
mean_values
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  1.096310
# dtype: float64

# %%
outliers_indices = np.where(outlier_scores == -1)[0]

# %%
df_filled = df.copy()
for col in df.columns:
    df_filled.iloc[outliers_indices,df.columns.get_loc(col)] = mean_values[col]

df_filled.loc[np.where(outlier_scores == -1)[0]]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 324        8.319637          0.527821     0.270976        2.538806   0.087467
# 325        8.319637          0.527821     0.270976        2.538806   0.087467
# 354        8.319637          0.527821     0.270976        2.538806   0.087467
# 374        8.319637          0.527821     0.270976        2.538806   0.087467
# 396        8.319637          0.527821     0.270976        2.538806   0.087467
# 400        8.319637          0.527821     0.270976        2.538806   0.087467
# 442        8.319637          0.527821     0.270976        2.538806   0.087467
# 444        8.319637          0.527821     0.270976        2.538806   0.087467
# 480        8.319637          0.527821     0.270976        2.538806   0.087467
# 530        8.319637          0.527821     0.270976        2.538806   0.087467
# 535        8.319637          0.527821     0.270976        2.538806   0.087467
# ...

# %%
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from sklearn import ensemble,linear_model,gaussian_process,naive_bayes,neighbors,svm,tree,discriminant_analysis,model_selection
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

from warnings import filterwarnings
filterwarnings("ignore")

# %%
Target = "quality"
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   1.096310   0.407354  0.00000   1.0000
#
#                            50%        75%        max
# ...

# %%
scale = StandardScaler()
df_scaled = pd.DataFrame(
    scale.fit_transform(df.drop(Target, axis=1).values) ,
    columns=df.drop(Target, axis=1).columns)  #sınıf sutününü dışarıdan bırakıypruzz
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol
# 0 -0.960246
# 1 -0.584777
# 2 -0.584777
# ...

# %%
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol
# 0 -0.960246
# 1 -0.584777
# 2 -0.584777
# ...

# %%
df_scaled[Target] = df[Target]

# %%
df_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3       1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
# 3             0.107592              0.411500  0.664277 -0.979104  -0.461180
# 4            -0.466193             -0.379133  0.558274  1.288643  -0.579207
#
#     alcohol  quality
# 0 -0.960246        1
# ...

# %%
X = df_scaled.drop(Target, axis=1)
y = df_scaled[Target]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
MLA = [
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),
    
    gaussian_process.GaussianProcessClassifier(),

    linear_model.LogisticRegression(),
    linear_model.PassiveAggressiveClassifier(),  # Düzeltildi
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),

    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),

    neighbors.KNeighborsClassifier(),

    svm.SVC(probability=True),
    svm.NuSVC(probability=True),
    svm.LinearSVC(),

    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),

    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis(),
    
    XGBClassifier(),
    
    MLPClassifier()
]

cv_split = model_selection.ShuffleSplit(n_splits=10,test_size=0.3,train_size=0.6,random_state=0)

MLA_columns = ['MLA Name','MLA Parameters','MLA Train Accuracy Mean','MLA Test Accuracy Mean',
               'MLA Test Accuracy 3*STD','MLA Time']
MLA_compare = pd.DataFrame(columns=MLA_columns)

Target = "quality"
MLA_predict = df["quality"]
column_names = df.drop("quality",axis=1).columns

# %%
row_index = 0
for alg in MLA:
    MLA_name = alg.__class__.__name__
    print(MLA_name)
    MLA_compare.loc[row_index, 'MLA Name'] = MLA_name

    MLA_compare.loc[row_index,'MLA Parameters'] = str(alg.get_params())

    alg.fit(X_train,y_train)
    MLA_predict[MLA_name] = alg.predict(df[column_names])

    cv_results = model_selection.cross_validate(alg,df_scaled[column_names],df[Target],
                                                cv=cv_split,return_train_score=True)

    MLA_compare.loc[row_index,'MLA Time'] = cv_results['fit_time'].mean()
    MLA_compare.loc[row_index,'MLA Train Accuracy Mean'] = cv_results['train_score'].mean()
    MLA_compare.loc[row_index,'MLA Test Accuracy Mean'] = cv_results['test_score'].mean()
    MLA_compare.loc[row_index,'MLA Test Accuracy 3*STD'] = cv_results['test_score'].std()*3

    row_index += 1


MLA_compare.sort_values(by=['MLA Test Accuracy Mean'],ascending=False,inplace=True)

MLA_compare
# Out:
# AdaBoostClassifier
# BaggingClassifier
# ExtraTreesClassifier
# GradientBoostingClassifier
# RandomForestClassifier
# GaussianProcessClassifier
# LogisticRegression
# PassiveAggressiveClassifier
# SGDClassifier
# Perceptron
# BernoulliNB
# GaussianNB
# KNeighborsClassifier
# SVC
# NuSVC
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 9
#       5 MLA_compare.loc[row_index, 'MLA Name'] = MLA_name
#       7 MLA_compare.loc[row_index,'MLA Parameters'] = str(alg.get_params())
# ----> 9 alg.fit(X_train,y_train)
#      10 MLA_predict[MLA_name] = alg.predict(df[column_names])
#      12 cv_results = model_selection.cross_validate(alg,df_scaled[column_names],df[Target],
#      13                                             cv=cv_split,return_train_score=True)
#
# ...
