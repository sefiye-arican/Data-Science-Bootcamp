# %%
# !pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/22/a5/a0b255295406ed54269814bc93723cfd1a0da63fb9aaf99e1364f07923e5/pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.5 MB 762.6 kB/s eta 0:00:15
#    ---------------------------------------- 0.1/11.5 MB 1.0 MB/s eta 0:00:12
# ...

# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/DELL/Desktop/Data/smartphones.csv')
# Out:
#                                             Smartphone     Brand  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model   RAM  Storage   Color Free  Final Price
# 0                C55   8.0    256.0  Yellow  Yes       231.60
# ...

# %%
df=pd.read_csv('C:/Users/DELL/Desktop/Data/smartphones.csv')
df.columns=['Akıllı telefon','Marka','Model','Hafıza','Depolama Alanı','Renk','İndirim','Fiyat']
df
# Out:
#                                         Akıllı telefon     Marka  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model  Hafıza  Depolama Alanı    Renk İndirim   Fiyat
# 0                C55     8.0           256.0  Yellow     Yes  231.60
# ...

# %%
df.head() #en baştaki satır bilgilerini gösterir
# Out:
#                                  Akıllı telefon     Marka           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#    Hafıza  Depolama Alanı    Renk İndirim   Fiyat
# 0     8.0           256.0  Yellow     Yes  231.60
# 1     4.0           128.0    Blue     Yes  279.00
# 2     4.0           128.0    Blue     Yes  179.01
# 3     6.0           128.0    Gray     Yes  279.99
# 4    12.0           512.0   White     Yes  799.00

# %%
df.tail() #en son satır bilgilerini gösterir
# Out:
#                                         Akıllı telefon   Marka          Model  \
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre  Xiaomi   Redmi Note 8
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre  Xiaomi  Redmi Note 8T
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre  Xiaomi   Redmi Note 9
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre  Xiaomi        Note 9S
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre  Xiaomi        Note 9S
#
#       Hafıza  Depolama Alanı   Renk İndirim   Fiyat
# 1811     4.0            64.0   Blue     Yes  249.01
# 1812     4.0           128.0   Blue     Yes  200.00
# 1813     4.0           128.0  White     Yes  269.00
# 1814     4.0            64.0   Gray     Yes  211.00
# 1815     6.0           128.0   Gray     Yes  289.00

# %%
df.shape #satır ve sütun bilgisi
# Out:
# (1816, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 0 to 1815
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Akıllı telefon  1816 non-null   object
#  1   Marka           1816 non-null   object
#  2   Model           1816 non-null   object
#  3   Hafıza          1333 non-null   float64
#  4   Depolama Alanı  1791 non-null   float64
#  5   Renk            1816 non-null   object
#  6   İndirim         1816 non-null   object
#  7   Fiyat           1816 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 113.6+ KB

# %%
df_yeni=df.drop(['İndirim','Renk'], axis=1)
df_yeni
# Out:
#                                         Akıllı telefon     Marka  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model  Hafıza  Depolama Alanı   Fiyat
# 0                C55     8.0           256.0  231.60
# 1         Galaxy M23     4.0           128.0  279.00
# ...

# %%
df.drop(['Fiyat'], axis=1, inplace=True)  #fiyatı df üstünden silmiş olduk
df.head()
# Out:
#                                  Akıllı telefon     Marka           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#    Hafıza  Depolama Alanı    Renk İndirim    Puan
# 0     8.0           256.0  Yellow     Yes  2048.0
# 1     4.0           128.0    Blue     Yes   512.0
# 2     4.0           128.0    Blue     Yes   512.0
# 3     6.0           128.0    Gray     Yes   768.0
# 4    12.0           512.0   White     Yes  6144.0

# %%
df['Puan']=df['Hafıza']*df['Depolama Alanı']

# %%
df_2000=df[
df['Puan']>2000
]
df_2000
# Out:
#                                          Akıllı telefon    Marka  \
# 0                    Realme C55 8/256GB Sunshower Libre   Realme
# 4               Nothing Phone (2) 12/512GB Blanco Libre  Nothing
# 6               Nothing Phone (2) 12/256GB Blanco Libre  Nothing
# 9     Xiaomi Redmi Note 12 Pro 8/256GB Gris Grafito ...   Xiaomi
# 12                 Realme C55 8/256GB Rainy Night Libre   Realme
# ...                                                 ...      ...
# 1793  Samsung Galaxy Z Fold4 12/256GB Beige Libre + ...  Samsung
# 1794  Samsung Galaxy Z Fold4 12/512GB Verde Libre + ...  Samsung
# 1796             Xiaomi 11T Pro 5G 8/256GB Blanco Libre   Xiaomi
# 1797             Xiaomi Mi 10 8/256GB Verde Coral Libre   Xiaomi
# 1803          Xiaomi Mi Note 10 Pro 8/256GB Verde Libre   Xiaomi
#
#                Model  Hafıza  Depolama Alanı    Renk İndirim    Fiyat    Puan
# 0                C55     8.0           256.0  Yellow     Yes   231.60  2048.0
# ...

# %%
df_puan=df['Puan']
df.drop(['Puan'], axis=1, inplace=True)
df.head()
# Out:
#                                  Akıllı telefon     Marka           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#    Hafıza  Depolama Alanı    Renk İndirim
# 0     8.0           256.0  Yellow     Yes
# 1     4.0           128.0    Blue     Yes
# 2     4.0           128.0    Blue     Yes
# 3     6.0           128.0    Gray     Yes
# 4    12.0           512.0   White     Yes

# %%
df_puan
# Out:
# 0       2048.0
# 1        512.0
# 2        512.0
# 3        768.0
# 4       6144.0
#          ...
# 1811     256.0
# 1812     512.0
# 1813     512.0
# 1814     256.0
# 1815     768.0
# Name: Puan, Length: 1816, dtype: float64

# %%
pd.concat([df,df_puan])
# Out:
#                                     Akıllı telefon     Marka           Model  \
# 0               Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1         Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2     Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3         Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4          Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
# ...                                            ...       ...             ...
# 1811                                           NaN       NaN             NaN
# 1812                                           NaN       NaN             NaN
# 1813                                           NaN       NaN             NaN
# 1814                                           NaN       NaN             NaN
# 1815                                           NaN       NaN             NaN
#
# ...

# %%
df.describe() #kaç adet veri olduğunu, standart sapmasını, vb bilgileri görüntülemek için
# Out:
#            Hafıza  Depolama Alanı
# count  1333.00000     1791.000000
# mean      5.96099      162.652150
# std       2.66807      139.411605
# min       1.00000        2.000000
# 25%       4.00000       64.000000
# 50%       6.00000      128.000000
# 75%       8.00000      256.000000
# max      12.00000     1000.000000

# %%
df['Hafıza'].mean()  # Ortalama
df['Hafıza'].count()  # Değerlerin sayısı
df['Hafıza'].min()  # En küçük değer
df['Hafıza'].max()  # En büyük değer
df['Hafıza'].sum()  # Toplam
df['Hafıza'].std()  # Standart sapma
# Out:
# 2.668069942275087

# %%
df
# Out:
#                                         Akıllı telefon     Marka  \
# 0                   Realme C55 8/256GB Sunshower Libre    Realme
# 1             Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung
# 2         Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola
# 3             Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi
# 4              Nothing Phone (2) 12/512GB Blanco Libre   Nothing
# ...                                                ...       ...
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre    Xiaomi
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre    Xiaomi
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre    Xiaomi
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre    Xiaomi
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre    Xiaomi
#
#                Model  Hafıza  Depolama Alanı    Renk İndirim
# 0                C55     8.0           256.0  Yellow     Yes
# 1         Galaxy M23     4.0           128.0    Blue     Yes
# ...
